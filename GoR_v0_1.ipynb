# %% [markdown]
# ###Install Dependencies

# %%
#!pip install torch==2.6.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
#!pip install dgl -f https://data.dgl.ai/wheels/torch-2.1.1/cu124/repo.html
# !pip install openai
# !pip install pandas
# !pip install langchain
# !pip install langchain-core
# !pip install langchain-community
# !pip install langchain-experimental
# !pip install tiktoken
# !pip install tqdm
# !pip install bert_score
# !pip install rouge_score
# !pip install networkx
#!pip install faiss-gpu-cu12
# !pip install faiss-gpu
# !pip install transformers==4.36.0
# !conda install -c conda-forge typing_extensions 
# !pip install torchdata==0.7.1

#Dependencies for loading datasets
# !pip install -U datasets
# !pip install pyarrow


"""
if Error 'version `GLIBCXX_3.4.29' not found ' raised for dgl:
    conda install -c conda-forge libstdcxx-ng=12
    strings $CONDA_PREFIX/lib/libstdc++.so.6 | grep GLIBCXX_3.4.29
"""

# %% [markdown]
# <h2>This is Forked Repo of Graph Of Records Github Repo</h2>
# <h3>Changes:</h3>
# <ol>
#     <li>get_response_by_ollama is Getting used insted of making api calls to toghether.api</li>
#     <li>Now We can Check How Far Sample Are processed and prevent Proccesing them Again</li>
# </ol>

# %%
#!git clone https://github.com/ulab-uiuc/GoR.git
! git clone https://github.com/Aminapmm/GoR_UI.git
# %cd GoR_UI

# !mkdir -p ./data
# Out:
# Cloning into 'GoR_UI'...
#
# /teamspace/studios/this_studio/GoR/GoR_UI

# %% [markdown]
# </h3>Load Datasets from HG</h3>

# %% [markdown]
# <ul>
#     <li>
# <b>Squality Dataset</b><br>
# https://github.com/nyu-mll/SQuALITY.git
#     </li>
#     <li>
# <b>Govreport Dataset</b><br>
# https://huggingface.co/datasets/ccdv/govreport-summarization/tree/refs%2Fconvert%2Fparquet/document
#     </li>
#
# <li>
#     <b>Booksum</b><br>
#     https://huggingface.co/datasets/kmfoda/booksum
#     </li>
# </ul>

# %% [markdown]
# <p>Steps to load Datasets:</p>
# <ol>
# <li>Change Dir to ./data</li>
# <li>load&store booksum using hugging_face load_dataset module</li>
# <li>clone GovReport and SQuality Datasets</li>
# </ol>

# %% [markdown]
# <h4>Booksum Dataset</h4>

# %%
from datasets import load_dataset

ds = load_dataset("kmfoda/booksum")

import os

# Create a directory in your Google Drive for the dataset
drive_path = './data/Booksum'
os.makedirs(drive_path, exist_ok=True)

# Save each split as a CSV file
for split in ds.keys():
  ds[split].to_csv(f"{drive_path}/{split}.csv")
# Out:
# README.md:   0%|          | 0.00/3.33k [00:00<?, ?B/s]
# train.csv:   0%|          | 0.00/295M [00:00<?, ?B/s]
# dev.csv:   0%|          | 0.00/40.4M [00:00<?, ?B/s]
# test.csv:   0%|          | 0.00/43.4M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9600 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1484 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1431 [00:00<?, ? examples/s]
# Creating CSV from Arrow format:   0%|          | 0/10 [00:00<?, ?ba/s]
# Creating CSV from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# Creating CSV from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]

# %% [markdown]
# ###Query Simulation and Graph Construction

# %%
import torch
print(torch.__version__)
print("PyTorch CUDA available:", torch.cuda.is_available())
import dgl
print("DGL imported successfully")
# Out:
# 2.4.1+cu121
# PyTorch CUDA available: True
# DGL imported successfully

# %%
# %cd "~/GoR_UI"
# Out:
# /teamspace/studios/this_studio/GoR_UI
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# Train set
# !python graph_construction.py --cuda 0 --dataset booksum --train --llm_model 'mixtral:8x7b'

# Test Set
# !python graph_construction.py --cuda 0 --dataset booksum --llm_model "mixtral:8x7b"

# %%
# Train set
# !python graph_construction.py --cuda 0 --dataset squality --train --llm_model 'mixtral:8x7b'

# Test Set
# !python graph_construction.py --cuda 0 --dataset squality --llm_model "mixtral:8x7b"
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/modeling_utils.py:519: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location=map_location)
# [2025-05-30 08:23:12] #Data: 100
# [2025-05-30 08:23:20] Generate Query 1/30:
# What is the significance of the vintage celebration in Lovenbroy, where people tramp out the grapes and many young children are born shortly after?
# [2025-05-30 08:23:24] Generate Query 2/30:
# What is the purpose of Croania accepting four hundred and ninety surplus tractors from Retief, and what are their plans for using them, especially if Croanie allegedly has no ore to mine?
# [2025-05-30 08:23:29] Generate Query 3/30:
# "What is the significance of assigning Retief to a sensitive desk in the Manpower Utilization Directorative, Division of Libraries and Education, and what is the potential impact of Bogan participation in the Exchange Program on their aggressions?"
# [2025-05-30 08:23:31] Generate Query 4/30:
# Who is referring to themselves as the "prize" in this context?
# [2025-05-30 08:23:35] Generate Query 5/30:
# "What can you tell me about the relationship between Croanie, Boge, and Earth, particularly any past attempts at taking over and their current standing with one another?"
# [2025-05-30 08:23:37] Generate Query 6/30:
# "What can you tell me about the relationship between Croanie, Boge, and Earth, and how it relates to any important resources or past invasion attempts?"
# [2025-05-30 08:23:41] Generate Query 7/30:
# What is the issue with this year's wine crop that Arapoulos is worried about, given that the crop is not the problem and they haven't lost their markets?
# [2025-05-30 08:23:45] Generate Query 8/30:
# What issue does Hank Arapoulous, a farmer from Lovenbroy, want to discuss with Retief, who works for the Culture bunch, regarding the upcoming wine crop harvest?
# [2025-05-30 08:23:49] Generate Query 9/30:
# "What information is Retief requesting from Miss Furkle regarding MEDDLE's recent shipments, and why is he taking full responsibility for it?"
# [2025-05-30 08:23:53] Generate Query 10/30:
# "What can you tell me about the mix-up regarding the students' destination being Lovenbroy instead of d'Land, and the unexpected presence of tractors for industrial use?"
# [2025-05-30 08:23:57] Generate Query 11/30:
# "What can you tell about how the Bogan students will behave under pressure, based on how one of them reacted to an authority figure upon arrival at the Customs enclosure?"
# [2025-05-30 08:24:00] Generate Query 12/30:
# "What is the reason for the diplomatic baggage of Mr. Gulver being impounded by the Armaments Control Commission, and who has informed Retief about this situation?"
# [2025-05-30 08:24:03] Generate Query 13/30:
# "What can you tell me about Retief's unannounced arrival and his role in bringing two thousand Bogan workers?"
# [2025-05-30 08:24:08] Generate Query 14/30:
# "What can you tell me about the student movements planned under the current program and the recent shipments of MEDDLE, given the interest in dispatching more students to an under-populated world in a specific region of space?"
# [2025-05-30 08:24:21] Generate Query 15/30:
# "What is the purpose of Retief's visit to Hank's place, and what issue are they discussing related to labor and field hands?"
# [2025-05-30 08:24:24] Generate Query 16/30:
# What institution are the Bogan students that Karsh is arranging a meal for bound for, and why does Miss Furkle seem hesitant to provide this information?
# [2025-05-30 08:24:28] Generate Query 17/30:
# "How many tractors will Croanie be receiving under the MEDDLE program, and where can I find information about the Bolo model WV tractor used in mining?"
# [2025-05-30 08:24:32] Generate Query 18/30:
# How many students is Mr. Gulver arranging for transportation to Croanie, and what is the given document's context regarding this student placement?
# [2025-05-30 08:24:35] Generate Query 19/30:
# What kind of wine is Bacchus wine and what is unique about it, according to Arapoulous' description?
# [2025-05-30 08:24:38] Generate Query 20/30:
# What are the different seasons on Lovenbroy, and what activities and local resources do the inhabitants typically associate with each season?
# [2025-05-30 08:24:44] Generate Query 21/30:
# "What is the reason for Whaffle, as Chief of MEDDLE, being uninterested in probing into MUDDLE's business or the Special Committee's request for mining equipment, and why does he mention MEDDLE's policy of 'first come, first served'?"
# [2025-05-30 08:24:47] Generate Query 22/30:
# What type of behavior is expected from the Bogan students after arriving at the Customs enclosure and where will they be staying during their visit?
# [2025-05-30 08:24:50] Generate Query 23/30:
# "What are the plans for the students and their baggage, and is there a possibility of arranging a meal for them while they wait for their departure?"
# [2025-05-30 08:24:54] Generate Query 24/30:
# What is the significance of the vintage season and manual grape picking for the Lovenbroy community, as described by Retief, and why is it critical for their loan repayment?
# [2025-05-30 08:24:58] Generate Query 25/30:
# "What is the situation with the baggage and why does Retief want to go to the port to see the students off personally after giving Jim instructions over the phone?"
# [2025-05-30 08:25:01] Generate Query 26/30:
# "What is the purpose of Karsh's meeting with the group of students who are not over eighteen years old, and what is his relationship to them?"
# [2025-05-30 08:25:05] Generate Query 27/30:
# "What is the situation with the baggage and why does Retief believe it's best for him to personally see the students off at the port after giving instructions to Jim over the phone?"
# [2025-05-30 08:25:08] Generate Query 28/30:
# Who is Mr. Karsh and who is he meeting at the port where the Bogan students have arrived?
# [2025-05-30 08:25:11] Generate Query 29/30:
# What is the significance of the vintage season and the manual grape-picking process in maintaining the Lovenbroy community's tradition and financial stability?
# [2025-05-30 08:25:14] Generate Query 30/30:
# "How many tractors does Miss Furkle claim to have, and why is Retief questioning the accuracy of her statement?"
# [2025-05-30 08:25:14] Dense Retrieval...
# [2025-05-30 08:25:14] Retrieved Chunks: [13, 12, 14, 5, 10, 7]
# [2025-05-30 08:25:30] Graph Construction: 1/30
# Graph(num_nodes=7, num_edges=6,
#       ndata_schemes={'feat': Scheme(shape=(768,), dtype=torch.float32)}
#       edata_schemes={'w': Scheme(shape=(1,), dtype=torch.float32)})
# [2025-05-30 08:25:30] Dense Retrieval...
# [2025-05-30 08:25:30] Retrieved Chunks: [30, 31, 25, 17, 29, 18]
# [2025-05-30 08:25:54] Graph Construction: 2/30
# Graph(num_nodes=14, num_edges=12,
#       ndata_schemes={'feat': Scheme(shape=(768,), dtype=torch.float32)}
#       edata_schemes={'w': Scheme(shape=(1,), dtype=torch.float32)})
# [2025-05-30 08:25:54] Dense Retrieval...
# [2025-05-30 08:25:54] Retrieved Chunks: [15, 33, 16, 24, 25, 39]
# [2025-05-30 08:26:12] Graph Construction: 3/30
# Graph(num_nodes=21, num_edges=18,
#       ndata_schemes={'feat': Scheme(shape=(768,), dtype=torch.float32)}
#       edata_schemes={'w': Scheme(shape=(1,), dtype=torch.float32)})
# [2025-05-30 08:26:12] Dense Retrieval...
# [2025-05-30 08:26:12] Retrieved Chunks: [52, 9, 8, 51, 20, 42]
# [2025-05-30 08:26:21] Graph Construction: 4/30
# Graph(num_nodes=25, num_edges=24,
#       ndata_schemes={'feat': Scheme(shape=(768,), dtype=torch.float32)}
#       edata_schemes={'w': Scheme(shape=(1,), dtype=torch.float32)})
# [2025-05-30 08:26:21] Dense Retrieval...
# [2025-05-30 08:26:21] Retrieved Chunks: [41, 51, 8, 10, 13, 9]
# [2025-05-30 08:26:51] Graph Construction: 5/30
# Graph(num_nodes=28, num_edges=30,
#       ndata_schemes={'feat': Scheme(shape=(768,), dtype=torch.float32)}
#       edata_schemes={'w': Scheme(shape=(1,), dtype=torch.float32)})
# [2025-05-30 08:26:51] Dense Retrieval...
# [2025-05-30 08:26:51] Retrieved Chunks: [25, 26, 8, 10, 45, 27]
# [2025-05-30 08:27:26] Graph Construction: 6/30
# Graph(num_nodes=30, num_edges=36,
#       ndata_schemes={'feat': Scheme(shape=(768,), dtype=torch.float32)}
#       edata_schemes={'w': Scheme(shape=(1,), dtype=torch.float32)})
# [2025-05-30 08:27:26] Dense Retrieval...
# [2025-05-30 08:27:26] Retrieved Chunks: [34, 4, 6, 3, 5, 36]
# [2025-05-30 08:27:40] Graph Construction: 7/30
# Graph(num_nodes=33, num_edges=42,
#       ndata_schemes={'feat': Scheme(shape=(768,), dtype=torch.float32)}
#       edata_schemes={'w': Scheme(shape=(1,), dtype=torch.float32)})
# [2025-05-30 08:27:40] Dense Retrieval...
# [2025-05-30 08:27:40] Retrieved Chunks: [30, 35, 4, 31, 5, 48]

# %%
# Train set
# !python graph_construction.py --cuda 0 --dataset govreport --train --llm_model 'mixtral:8x7b'

# Test Set
# !python graph_construction.py --cuda 0 --dataset govreport --llm_model "mixtral:8x7b"

# %%
from utils import get_llm_response_via_ollama

get_llm_response_via_ollama("what is M.sc?").decode()
# Out:
# "\xa0M.Sc. (Master of Science) is an academic degree that is typically pursued after completing a Bachelor's degree in a science-related field. The duration of the program can vary, but it usually takes two years to complete.\n\nThe curriculum for an M.Sc. program generally includes advanced coursework in a specific area of science, such as biology, chemistry, physics, mathematics, or computer science. In addition to coursework, students are typically required to complete a research project or thesis under the guidance of a faculty advisor.\n\nThe M.Sc. degree can lead to a variety of career opportunities in academia, industry, government, and non-profit organizations. It can also provide a foundation for further study at the doctoral level (Ph.D.). The specific admission requirements for an M.Sc. program may vary depending on the institution and country, but typically include a bachelor's degree in a relevant field, a strong academic record, and sometimes GRE scores or letters of recommendation."

# %% [markdown]
# <h3>Precomputing BertScores</h3>

# %%
# DATASET Choices: qmsum, wcep, booksum, govreport, squality
# !python training_preparation.py --cuda 0 --dataset booksum
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# [2025-05-29 07:29:14] #Data: 951
#   0%|                                                   | 0/200 [00:00<?, ?it/s]/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# tokenizer_config.json: 100%|██████████████████| 52.0/52.0 [00:00<00:00, 506kB/s]
#
# config.json: 100%|█████████████████████████████| 792/792 [00:00<00:00, 6.98MB/s]
#
# vocab.json: 100%|████████████████████████████| 899k/899k [00:00<00:00, 13.8MB/s]
#
# merges.txt: 100%|████████████████████████████| 456k/456k [00:00<00:00, 25.8MB/s]
#
# pytorch_model.bin:   0%|                            | 0.00/3.04G [00:00<?, ?B/s]
# pytorch_model.bin:   1%|▎                   | 41.9M/3.04G [00:00<00:07, 389MB/s]
# pytorch_model.bin:   3%|▌                   | 94.4M/3.04G [00:00<00:06, 446MB/s]
# pytorch_model.bin:   5%|█                    | 147M/3.04G [00:00<00:06, 465MB/s]
# pytorch_model.bin:   7%|█▍                   | 199M/3.04G [00:00<00:05, 476MB/s]
# pytorch_model.bin:   8%|█▋                   | 252M/3.04G [00:00<00:05, 484MB/s]
# pytorch_model.bin:  10%|██                   | 304M/3.04G [00:00<00:05, 489MB/s]
# pytorch_model.bin:  12%|██▍                  | 357M/3.04G [00:00<00:05, 493MB/s]
# pytorch_model.bin:  13%|██▊                  | 409M/3.04G [00:00<00:05, 491MB/s]
# pytorch_model.bin:  15%|███▏                 | 461M/3.04G [00:00<00:05, 494MB/s]
# pytorch_model.bin:  17%|███▌                 | 514M/3.04G [00:01<00:05, 496MB/s]
# pytorch_model.bin:  19%|███▉                 | 566M/3.04G [00:01<00:04, 497MB/s]
# pytorch_model.bin:  20%|████▎                | 619M/3.04G [00:01<00:04, 495MB/s]
# pytorch_model.bin:  22%|████▋                | 671M/3.04G [00:01<00:04, 495MB/s]
# pytorch_model.bin:  24%|█████                | 724M/3.04G [00:01<00:10, 213MB/s]
# pytorch_model.bin:  25%|█████▎               | 765M/3.04G [00:02<00:16, 141MB/s]
# pytorch_model.bin:  27%|█████▌               | 807M/3.04G [00:02<00:13, 170MB/s]
# pytorch_model.bin:  28%|█████▉               | 860M/3.04G [00:02<00:10, 211MB/s]
# pytorch_model.bin:  30%|██████▎              | 912M/3.04G [00:02<00:08, 251MB/s]
# pytorch_model.bin:  31%|██████▌              | 954M/3.04G [00:03<00:19, 106MB/s]
# pytorch_model.bin:  33%|██████▋             | 1.01G/3.04G [00:04<00:14, 141MB/s]
# pytorch_model.bin:  35%|██████▌            | 1.05G/3.04G [00:05<00:23, 85.3MB/s]
# pytorch_model.bin:  36%|███████▏            | 1.09G/3.04G [00:05<00:17, 109MB/s]
# pytorch_model.bin:  38%|███████▌            | 1.14G/3.04G [00:05<00:13, 145MB/s]
# pytorch_model.bin:  39%|███████▊            | 1.18G/3.04G [00:05<00:16, 112MB/s]
# pytorch_model.bin:  40%|███████▌           | 1.22G/3.04G [00:06<00:19, 95.4MB/s]
# pytorch_model.bin:  41%|████████▏           | 1.25G/3.04G [00:06<00:15, 112MB/s]
# pytorch_model.bin:  42%|███████▉           | 1.27G/3.04G [00:07<00:23, 76.1MB/s]
# pytorch_model.bin:  42%|████████           | 1.29G/3.04G [00:07<00:23, 73.5MB/s]
# pytorch_model.bin:  44%|████████▎          | 1.32G/3.04G [00:07<00:21, 78.6MB/s]
# pytorch_model.bin:  44%|████████▍          | 1.34G/3.04G [00:08<00:28, 58.9MB/s]
# pytorch_model.bin:  45%|████████▌          | 1.36G/3.04G [00:08<00:23, 70.6MB/s]
# pytorch_model.bin:  47%|█████████▎          | 1.42G/3.04G [00:08<00:14, 114MB/s]
# pytorch_model.bin:  47%|████████▉          | 1.44G/3.04G [00:09<00:21, 74.1MB/s]
# pytorch_model.bin:  48%|█████████          | 1.46G/3.04G [00:09<00:22, 70.6MB/s]
# pytorch_model.bin:  82%|███████████████▌   | 2.49G/3.04G [00:21<00:07, 76.3MB/s]
# pytorch_model.bin:  83%|███████████████▋   | 2.51G/3.04G [00:21<00:07, 73.1MB/s]
# pytorch_model.bin:  84%|████████████████▊   | 2.55G/3.04G [00:21<00:04, 100MB/s]
# pytorch_model.bin:  85%|████████████████   | 2.57G/3.04G [00:22<00:06, 69.0MB/s]
# pytorch_model.bin:  85%|████████████████▏  | 2.59G/3.04G [00:22<00:06, 68.1MB/s]
# pytorch_model.bin:  87%|█████████████████▍  | 2.64G/3.04G [00:22<00:03, 111MB/s]
# pytorch_model.bin:  88%|█████████████████▋  | 2.68G/3.04G [00:22<00:02, 140MB/s]
# pytorch_model.bin:  89%|████████████████▉  | 2.72G/3.04G [00:23<00:04, 77.3MB/s]
# pytorch_model.bin:  91%|██████████████████▏ | 2.76G/3.04G [00:23<00:02, 106MB/s]
# pytorch_model.bin:  92%|█████████████████▍ | 2.79G/3.04G [00:24<00:03, 73.2MB/s]
# pytorch_model.bin:  93%|█████████████████▌ | 2.81G/3.04G [00:25<00:03, 73.8MB/s]
# pytorch_model.bin:  94%|█████████████████▊ | 2.85G/3.04G [00:25<00:02, 85.8MB/s]
# pytorch_model.bin:  95%|█████████████████▉ | 2.87G/3.04G [00:26<00:02, 63.7MB/s]
# pytorch_model.bin:  95%|██████████████████ | 2.89G/3.04G [00:26<00:01, 74.8MB/s]
# pytorch_model.bin:  96%|██████████████████▏| 2.92G/3.04G [00:26<00:01, 86.4MB/s]
# pytorch_model.bin:  97%|██████████████████▍| 2.94G/3.04G [00:26<00:01, 60.1MB/s]
# pytorch_model.bin:  97%|██████████████████▌| 2.96G/3.04G [00:27<00:01, 62.0MB/s]
# pytorch_model.bin:  99%|███████████████████▊| 3.01G/3.04G [00:27<00:00, 107MB/s]
# pytorch_model.bin: 100%|████████████████████| 3.04G/3.04G [00:28<00:00, 108MB/s]
# 100%|█████████████████████████████████████████| 200/200 [41:39<00:00, 12.50s/it]

# %%
from utils import *
g = load_nx("/teamspace/studios/this_studio/GoR_UI/graph/booksum_graph_198.graphml")
print(g.number_of_nodes())
for node,attr in g.nodes(data=True):
    print(f"node:{node}\n attr:{attr}\n =======")

# %% [markdown]
# <h3>Training GNN</h3>

# %%
# DATASET Choices: qmsum, wcep, booksum, govreport, squality
# !python train.py --cuda 0 --dataset booksum
# Out:
# [2025-05-29 10:56:25] In epoch 0, lr: 0.00100, loss: 7.6813, entropy: 4.2918
# [2025-05-29 10:56:28] In epoch 1, lr: 0.00100, loss: 5.6150, entropy: 4.1586
# [2025-05-29 10:56:31] In epoch 2, lr: 0.00100, loss: 4.7104, entropy: 3.8642
# [2025-05-29 10:56:34] In epoch 3, lr: 0.00100, loss: 4.0313, entropy: 3.5272
# [2025-05-29 10:56:37] In epoch 4, lr: 0.00100, loss: 3.4416, entropy: 3.2184
# [2025-05-29 10:56:40] In epoch 5, lr: 0.00100, loss: 2.9766, entropy: 2.8481
# [2025-05-29 10:56:43] In epoch 6, lr: 0.00099, loss: 2.5868, entropy: 2.6012
# [2025-05-29 10:56:46] In epoch 7, lr: 0.00099, loss: 2.2760, entropy: 2.3397
# [2025-05-29 11:02:59] In epoch 134, lr: 0.00002, loss: 0.3561, entropy: 0.2261
# [2025-05-29 11:03:02] In epoch 135, lr: 0.00002, loss: 0.4105, entropy: 0.2373
# [2025-05-29 11:03:05] In epoch 136, lr: 0.00002, loss: 0.3952, entropy: 0.2313
# [2025-05-29 11:03:08] In epoch 137, lr: 0.00002, loss: 0.3786, entropy: 0.2309
# [2025-05-29 11:03:11] In epoch 138, lr: 0.00001, loss: 0.4170, entropy: 0.2360
# [2025-05-29 11:03:13] In epoch 139, lr: 0.00001, loss: 0.3930, entropy: 0.2326
# [2025-05-29 11:03:16] In epoch 140, lr: 0.00001, loss: 0.4276, entropy: 0.2300
# [2025-05-29 11:03:19] In epoch 141, lr: 0.00001, loss: 0.4259, entropy: 0.2212
# [2025-05-29 11:03:22] In epoch 142, lr: 0.00001, loss: 0.3884, entropy: 0.2346
# [2025-05-29 11:03:25] In epoch 143, lr: 0.00000, loss: 0.4539, entropy: 0.2307
# [2025-05-29 11:03:28] In epoch 144, lr: 0.00000, loss: 0.4300, entropy: 0.2333
# [2025-05-29 11:03:31] In epoch 145, lr: 0.00000, loss: 0.4228, entropy: 0.2289
# [2025-05-29 11:03:34] In epoch 146, lr: 0.00000, loss: 0.3994, entropy: 0.2264
# [2025-05-29 11:03:37] In epoch 147, lr: 0.00000, loss: 0.4187, entropy: 0.2388
# [2025-05-29 11:03:40] In epoch 148, lr: 0.00000, loss: 0.4209, entropy: 0.2301
# [2025-05-29 11:03:43] In epoch 149, lr: 0.00000, loss: 0.4442, entropy: 0.2340

# %%
# Generate summary results
# !python eval.py --cuda 0 --dataset booksum --llm_model "mixtral:8x7b"
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/modeling_utils.py:519: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location=map_location)
# [2025-05-30 07:38:10] #Data: 132
# /teamspace/studios/this_studio/GoR_UI/eval.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# [2025-05-30 07:38:12] Dense Retrieval...
# [2025-05-30 07:38:12] Retrieved Chunks: [84, 31, 76, 24, 73, 50]
# [2025-05-30 07:38:31] Dense Retrieval...
# [2025-05-30 07:38:31] Retrieved Chunks: [57, 42, 28, 2, 36, 3]
# [2025-05-30 07:39:08] Dense Retrieval...
# [2025-05-30 07:39:08] Retrieved Chunks: [119, 14, 112, 125, 71, 94]
# [2025-05-30 07:39:28] Dense Retrieval...
# [2025-05-30 07:39:28] Retrieved Chunks: [82, 84, 70, 45, 94, 81]
# [2025-05-30 07:40:05] Dense Retrieval...
# [2025-05-30 07:40:05] Retrieved Chunks: [95, 93, 96, 110, 42, 90]
# [2025-05-30 07:40:27] Dense Retrieval...
# [2025-05-30 07:40:27] Retrieved Chunks: [99, 86, 39, 33, 6, 50]
# [2025-05-30 07:40:50] Dense Retrieval...
# [2025-05-30 07:40:50] Retrieved Chunks: [90, 73, 44, 81, 104, 82]
# [2025-05-30 07:41:19] Dense Retrieval...
# [2025-05-30 07:41:19] Retrieved Chunks: [12, 15, 10, 30, 42, 72]
# [2025-05-30 07:41:35] Dense Retrieval...
# [2025-05-30 07:41:35] Retrieved Chunks: [84, 15, 143, 52, 49, 21]
# [2025-05-30 07:42:07] Dense Retrieval...
# [2025-05-30 07:42:07] Retrieved Chunks: [92, 23, 35, 105, 34, 109]
